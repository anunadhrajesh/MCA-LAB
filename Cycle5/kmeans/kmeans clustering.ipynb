# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

import pandas as pd
customers = pd.read_csv('customer_data.csv')
customers.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
points, cluster_indexes = make_blobs(n_samples=200, centers=4, cluster_std=0.8, random_state=0)

x = points[:, 0]

y = points[:, 1]

plt.scatter(x, y, s=50, alpha=0.7)

# %%
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(points)
predicted_cluster_indexes = kmeans.predict(points)
plt.scatter(x, y, c=predicted_cluster_indexes, s=50, alpha=0.7, cmap='viridis')

# %%
kmeans = KMeans(n_clusters=6, random_state=0)
kmeans.fit(points)
predicted_cluster_indexes = kmeans.predict(points)
plt.scatter(x, y, c=predicted_cluster_indexes, s=50, alpha=0.7, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=100)

# %%
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=100)

# %%
kmeans = KMeans(n_clusters=9, random_state=0)
kmeans.fit(points)
predicted_cluster_indexes = kmeans.predict(points)
plt.scatter(x, y, c=predicted_cluster_indexes, s=50, alpha=0.7, cmap='viridis')
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=100)

# %%
#Display the cluster labels of each point.(print cluster indexes)
print(predicted_cluster_indexes)
# Out:
# [8 5 7 4 1 3 5 7 3 3 7 1 5 0 8 3 4 4 2 6 2 0 1 5 8 6 2 6 6 3 2 3 5 8 5 3 0
#  3 3 4 2 2 2 7 6 5 7 4 2 3 4 5 0 4 8 2 0 1 2 8 4 7 8 3 2 7 6 4 0 5 1 6 7 7
#  5 2 0 0 8 1 4 3 8 6 0 7 7 1 5 5 2 4 4 3 3 6 0 2 8 3 2 6 8 2 2 0 3 8 1 7 4
#  5 5 6 1 3 6 5 2 7 4 5 3 1 7 0 7 5 6 3 0 8 7 2 2 5 2 4 1 4 1 0 8 6 5 1 3 8
#  0 4 4 2 7 5 6 3 4 5 2 6 4 1 1 0 0 2 7 1 8 0 6 7 0 2 4 2 3 3 5 0 7 1 3 6 7
#  5 5 2 3 2 6 1 3 2 5 5 0 7 2 6]
